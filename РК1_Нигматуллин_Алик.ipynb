# %% [markdown]
# # РК №1 Нигматуллина Алика ИУ5-64Б

# %% [markdown]
# #### Задача №2.
# Для заданного набора данных проведите обработку пропусков в данных для одного категориального и одного количественного признака. Какие способы обработки пропусков в данных для категориальных и количественных признаков Вы использовали? Какие признаки Вы будете использовать для дальнейшего построения моделей машинного обучения и почему?

# %% [markdown]
# #### Датасет №4
# https://www.kaggle.com/datasets/johnsmith88/heart-disease-dataset

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import matplotlib
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8)

pd.options.mode.chained_assignment = None
# %matplotlib inline
sns.set(style="ticks")

# %%
data = pd.read_csv('./heart.csv', sep=",")
df = data

# %%
data.shape
# Out:
# (1025, 14)

# %%
# shape and data types of the data
print(data.shape)
print(data.dtypes)
# Out:
# (1025, 14)
# age           int64
# sex           int64
# cp            int64
# trestbps      int64
# chol          int64
# fbs           int64
# restecg       int64
# thalach       int64
# exang         int64
# oldpeak     float64
# slope         int64
# ca            int64
# thal          int64
# target        int64
# dtype: object

# %%
data.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %% [markdown]
# ### Создание категориального признака
# В данном датасете нет категориального признака не в числовом виде, поэтому самостоятельно добавим его по полю thal: 0 = normal; 1 = fixed defect; 2 = reversable defect

# %%
# Определите условия для каждой категории
conditions = [
    data['thal'] == 1, # normal
    data['thal'] == 2, # fixed defect
    data['thal'] == 3 # reversable defect
]

# Определите соответствующие категории
choices = ['normal', 'fixed_defect', 'reversable_defect']

# Примените условия к датафрейму
data['thal_category'] = np.select(conditions, choices, default='unknown')

# %%
data.head(30)
# Out:
#     age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0    52    1   0       125   212    0        1      168      0      1.0
# 1    53    1   0       140   203    1        0      155      1      3.1
# 2    70    1   0       145   174    0        1      125      1      2.6
# 3    61    1   0       148   203    0        1      161      0      0.0
# 4    62    0   0       138   294    1        1      106      0      1.9
# 5    58    0   0       100   248    0        0      122      0      1.0
# 6    58    1   0       114   318    0        2      140      0      4.4
# 7    55    1   0       160   289    0        0      145      1      0.8
# 8    46    1   0       120   249    0        0      144      0      0.8
# 9    54    1   0       122   286    0        0      116      1      3.2
# 10   71    0   0       112   149    0        1      125      0      1.6
# 11   43    0   0       132   341    1        0      136      1      3.0
# 12   34    0   1       118   210    0        1      192      0      0.7
# 13   51    1   0       140   298    0        1      122      1      4.2
# 14   52    1   0       128   204    1        1      156      1      1.0
# 15   34    0   1       118   210    0        1      192      0      0.7
# 16   51    0   2       140   308    0        0      142      0      1.5
# 17   54    1   0       124   266    0        0      109      1      2.2
# 18   50    0   1       120   244    0        1      162      0      1.1
# 19   58    1   2       140   211    1        0      165      0      0.0
# 20   60    1   2       140   185    0        0      155      0      3.0
# 21   67    0   0       106   223    0        1      142      0      0.3
# 22   45    1   0       104   208    0        0      148      1      3.0
# 23   63    0   2       135   252    0        0      172      0      0.0
# 24   42    0   2       120   209    0        1      173      0      0.0
# 25   61    0   0       145   307    0        0      146      1      1.0
# 26   44    1   2       130   233    0        1      179      1      0.4
# 27   58    0   1       136   319    1        0      152      0      0.0
# 28   56    1   2       130   256    1        0      142      1      0.6
# 29   55    0   0       180   327    0        2      117      1      3.4
#
#     slope  ca  thal  target      thal_category
# 0       2   2     3       0  reversable_defect
# 1       0   0     3       0  reversable_defect
# 2       0   0     3       0  reversable_defect
# 3       2   1     3       0  reversable_defect
# 4       1   3     2       0       fixed_defect
# 5       1   0     2       1       fixed_defect
# 6       0   3     1       0             normal
# 7       1   1     3       0  reversable_defect
# 8       2   0     3       0  reversable_defect
# 9       1   2     2       0       fixed_defect
# 10      1   0     2       1       fixed_defect
# 11      1   0     3       0  reversable_defect
# 12      2   0     2       1       fixed_defect
# 13      1   3     3       0  reversable_defect
# 14      1   0     0       0            unknown
# 15      2   0     2       1       fixed_defect
# 16      2   1     2       1       fixed_defect
# 17      1   1     3       0  reversable_defect
# 18      2   0     2       1       fixed_defect
# 19      2   0     2       1       fixed_defect
# 20      1   0     2       0       fixed_defect
# 21      2   2     2       1       fixed_defect
# 22      1   0     2       1       fixed_defect
# 23      2   0     2       1       fixed_defect
# 24      1   0     2       1       fixed_defect
# 25      1   0     3       0  reversable_defect
# 26      2   0     2       1       fixed_defect
# 27      2   2     2       0       fixed_defect
# 28      1   1     1       0             normal
# 29      1   0     2       0       fixed_defect

# %% [markdown]
# ###  Замена на пропуски часть значений категориального признака
# В данном датасете нет пропусков вообще, поэтому самостоятельно добавим их в категориальное поле

# %%
# Проверим наличие пустых значений
# Цикл по колонкам датасета
for col in data.columns:
    # Количество пустых значений - все значения заполнены
    temp_null_count = data[data[col].isnull()].shape[0]
    print('{} - {}'.format(col, temp_null_count))
# Out:
# age - 0
# sex - 0
# cp - 0
# trestbps - 0
# chol - 0
# fbs - 0
# restecg - 0
# thalach - 0
# exang - 0
# oldpeak - 0
# slope - 0
# ca - 0
# thal - 0
# target - 0
# thal_category - 0

# %%
# Количество пропусков, которые будут добавлены в категориальном признаке
n_nan = 246

# Выбираем случайные индексы для добавления пропусков в категориальном признаке
index_nan = np.random.choice(data['thal_category'].size, n_nan, replace=False)

# Добавляем пропуски в поле thal_category
data['thal_category'].iloc[index_nan] = np.nan

# %%
# Количество пропусков, которые будут добавлены в количественном признаке
n_nan = 328

# Выбираем случайные индексы для добавления пропусков в количественном признаке
index_nan = np.random.choice(data['trestbps'].size, n_nan, replace=False)

# Добавляем пропуски в поле trestbps
data['trestbps'].iloc[index_nan] = np.nan

# %%
data.head(30)
# Out:
#     age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0    52    1   0     125.0   212    0        1      168      0      1.0
# 1    53    1   0     140.0   203    1        0      155      1      3.1
# 2    70    1   0     145.0   174    0        1      125      1      2.6
# 3    61    1   0     148.0   203    0        1      161      0      0.0
# 4    62    0   0     138.0   294    1        1      106      0      1.9
# 5    58    0   0     100.0   248    0        0      122      0      1.0
# 6    58    1   0     114.0   318    0        2      140      0      4.4
# 7    55    1   0       NaN   289    0        0      145      1      0.8
# 8    46    1   0       NaN   249    0        0      144      0      0.8
# 9    54    1   0       NaN   286    0        0      116      1      3.2
# 10   71    0   0       NaN   149    0        1      125      0      1.6
# 11   43    0   0     132.0   341    1        0      136      1      3.0
# 12   34    0   1       NaN   210    0        1      192      0      0.7
# 13   51    1   0     140.0   298    0        1      122      1      4.2
# 14   52    1   0       NaN   204    1        1      156      1      1.0
# 15   34    0   1       NaN   210    0        1      192      0      0.7
# 16   51    0   2     140.0   308    0        0      142      0      1.5
# 17   54    1   0     124.0   266    0        0      109      1      2.2
# 18   50    0   1     120.0   244    0        1      162      0      1.1
# 19   58    1   2     140.0   211    1        0      165      0      0.0
# 20   60    1   2       NaN   185    0        0      155      0      3.0
# 21   67    0   0       NaN   223    0        1      142      0      0.3
# 22   45    1   0       NaN   208    0        0      148      1      3.0
# 23   63    0   2     135.0   252    0        0      172      0      0.0
# 24   42    0   2     120.0   209    0        1      173      0      0.0
# 25   61    0   0       NaN   307    0        0      146      1      1.0
# 26   44    1   2     130.0   233    0        1      179      1      0.4
# 27   58    0   1       NaN   319    1        0      152      0      0.0
# 28   56    1   2     130.0   256    1        0      142      1      0.6
# 29   55    0   0     180.0   327    0        2      117      1      3.4
#
#     slope  ca  thal  target      thal_category
# 0       2   2     3       0  reversable_defect
# 1       0   0     3       0                NaN
# 2       0   0     3       0  reversable_defect
# 3       2   1     3       0  reversable_defect
# 4       1   3     2       0                NaN
# 5       1   0     2       1       fixed_defect
# 6       0   3     1       0             normal
# 7       1   1     3       0                NaN
# 8       2   0     3       0  reversable_defect
# 9       1   2     2       0       fixed_defect
# 10      1   0     2       1       fixed_defect
# 11      1   0     3       0  reversable_defect
# 12      2   0     2       1       fixed_defect
# 13      1   3     3       0  reversable_defect
# 14      1   0     0       0            unknown
# 15      2   0     2       1       fixed_defect
# 16      2   1     2       1       fixed_defect
# 17      1   1     3       0  reversable_defect
# 18      2   0     2       1       fixed_defect
# 19      2   0     2       1       fixed_defect
# 20      1   0     2       0       fixed_defect
# 21      2   2     2       1       fixed_defect
# 22      1   0     2       1       fixed_defect
# 23      2   0     2       1                NaN
# 24      1   0     2       1       fixed_defect
# 25      1   0     3       0  reversable_defect
# 26      2   0     2       1                NaN
# 27      2   2     2       0                NaN
# 28      1   1     1       0             normal
# 29      1   0     2       0       fixed_defect

# %% [markdown]
#  ## Обработка пропусков в данных для категориального признака thal_category
#  Будет выполняться за счёт метода "Внедрение значений" - *импьютация* со стратегией "most_frequent"

# %%
# Импьютация наиболее частыми значениями
from sklearn.impute import SimpleImputer# Фильтр для проверки заполнения пустых значений
imp = SimpleImputer(missing_values=np.nan, strategy='most_frequent')
data_imp = imp.fit_transform(data[['thal_category']])
data_imp[0:30]
# Out:
# array([['reversable_defect'],
#        ['fixed_defect'],
#        ['reversable_defect'],
#        ['reversable_defect'],
#        ['fixed_defect'],
#        ['fixed_defect'],
#        ['normal'],
#        ['fixed_defect'],
#        ['reversable_defect'],
#        ['fixed_defect'],
#        ['fixed_defect'],
#        ['reversable_defect'],
#        ['fixed_defect'],
#        ['reversable_defect'],
#        ['unknown'],
#        ['fixed_defect'],
#        ['fixed_defect'],
#        ['reversable_defect'],
#        ['fixed_defect'],
#        ['fixed_defect'],
#        ['fixed_defect'],
#        ['fixed_defect'],
#        ['fixed_defect'],
#        ['fixed_defect'],
#        ['fixed_defect'],
#        ['reversable_defect'],
#        ['fixed_defect'],
#        ['fixed_defect'],
#        ['normal'],
#        ['fixed_defect']], dtype=object)

# %%
data[['thal_category']] = data_imp
data.head(30)
# Out:
#     age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0    52    1   0     125.0   212    0        1      168      0      1.0
# 1    53    1   0     140.0   203    1        0      155      1      3.1
# 2    70    1   0     145.0   174    0        1      125      1      2.6
# 3    61    1   0     148.0   203    0        1      161      0      0.0
# 4    62    0   0     138.0   294    1        1      106      0      1.9
# 5    58    0   0     100.0   248    0        0      122      0      1.0
# 6    58    1   0     114.0   318    0        2      140      0      4.4
# 7    55    1   0       NaN   289    0        0      145      1      0.8
# 8    46    1   0       NaN   249    0        0      144      0      0.8
# 9    54    1   0       NaN   286    0        0      116      1      3.2
# 10   71    0   0       NaN   149    0        1      125      0      1.6
# 11   43    0   0     132.0   341    1        0      136      1      3.0
# 12   34    0   1       NaN   210    0        1      192      0      0.7
# 13   51    1   0     140.0   298    0        1      122      1      4.2
# 14   52    1   0       NaN   204    1        1      156      1      1.0
# 15   34    0   1       NaN   210    0        1      192      0      0.7
# 16   51    0   2     140.0   308    0        0      142      0      1.5
# 17   54    1   0     124.0   266    0        0      109      1      2.2
# 18   50    0   1     120.0   244    0        1      162      0      1.1
# 19   58    1   2     140.0   211    1        0      165      0      0.0
# 20   60    1   2       NaN   185    0        0      155      0      3.0
# 21   67    0   0       NaN   223    0        1      142      0      0.3
# 22   45    1   0       NaN   208    0        0      148      1      3.0
# 23   63    0   2     135.0   252    0        0      172      0      0.0
# 24   42    0   2     120.0   209    0        1      173      0      0.0
# 25   61    0   0       NaN   307    0        0      146      1      1.0
# 26   44    1   2     130.0   233    0        1      179      1      0.4
# 27   58    0   1       NaN   319    1        0      152      0      0.0
# 28   56    1   2     130.0   256    1        0      142      1      0.6
# 29   55    0   0     180.0   327    0        2      117      1      3.4
#
#     slope  ca  thal  target      thal_category
# 0       2   2     3       0  reversable_defect
# 1       0   0     3       0       fixed_defect
# 2       0   0     3       0  reversable_defect
# 3       2   1     3       0  reversable_defect
# 4       1   3     2       0       fixed_defect
# 5       1   0     2       1       fixed_defect
# 6       0   3     1       0             normal
# 7       1   1     3       0       fixed_defect
# 8       2   0     3       0  reversable_defect
# 9       1   2     2       0       fixed_defect
# 10      1   0     2       1       fixed_defect
# 11      1   0     3       0  reversable_defect
# 12      2   0     2       1       fixed_defect
# 13      1   3     3       0  reversable_defect
# 14      1   0     0       0            unknown
# 15      2   0     2       1       fixed_defect
# 16      2   1     2       1       fixed_defect
# 17      1   1     3       0  reversable_defect
# 18      2   0     2       1       fixed_defect
# 19      2   0     2       1       fixed_defect
# 20      1   0     2       0       fixed_defect
# 21      2   2     2       1       fixed_defect
# 22      1   0     2       1       fixed_defect
# 23      2   0     2       1       fixed_defect
# 24      1   0     2       1       fixed_defect
# 25      1   0     3       0  reversable_defect
# 26      2   0     2       1       fixed_defect
# 27      2   2     2       0       fixed_defect
# 28      1   1     1       0             normal
# 29      1   0     2       0       fixed_defect

# %% [markdown]
# ## Обработка пропусков в данных для количественного признака trestbps
#  Будет выполняться за счёт метода "Внедрение значений" - *импьютация* со стратегий "median"

# %%
# Импьютация медианой
from sklearn.impute import SimpleImputer# Фильтр для проверки заполнения пустых значений
imp2 = SimpleImputer(missing_values=np.nan, strategy='median')
data_imp = imp2.fit_transform(data[['trestbps']])
data_imp[0:30]
# Out:
# array([[125.],
#        [140.],
#        [145.],
#        [148.],
#        [138.],
#        [100.],
#        [114.],
#        [130.],
#        [130.],
#        [130.],
#        [130.],
#        [132.],
#        [130.],
#        [140.],
#        [130.],
#        [130.],
#        [140.],
#        [124.],
#        [120.],
#        [140.],
#        [130.],
#        [130.],
#        [130.],
#        [135.],
#        [120.],
#        [130.],
#        [130.],
#        [130.],
#        [130.],
#        [180.]])

# %%
data[['trestbps']] = data_imp
data.head(30)
# Out:
#     age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0    52    1   0     125.0   212    0        1      168      0      1.0
# 1    53    1   0     140.0   203    1        0      155      1      3.1
# 2    70    1   0     145.0   174    0        1      125      1      2.6
# 3    61    1   0     148.0   203    0        1      161      0      0.0
# 4    62    0   0     138.0   294    1        1      106      0      1.9
# 5    58    0   0     100.0   248    0        0      122      0      1.0
# 6    58    1   0     114.0   318    0        2      140      0      4.4
# 7    55    1   0     130.0   289    0        0      145      1      0.8
# 8    46    1   0     130.0   249    0        0      144      0      0.8
# 9    54    1   0     130.0   286    0        0      116      1      3.2
# 10   71    0   0     130.0   149    0        1      125      0      1.6
# 11   43    0   0     132.0   341    1        0      136      1      3.0
# 12   34    0   1     130.0   210    0        1      192      0      0.7
# 13   51    1   0     140.0   298    0        1      122      1      4.2
# 14   52    1   0     130.0   204    1        1      156      1      1.0
# 15   34    0   1     130.0   210    0        1      192      0      0.7
# 16   51    0   2     140.0   308    0        0      142      0      1.5
# 17   54    1   0     124.0   266    0        0      109      1      2.2
# 18   50    0   1     120.0   244    0        1      162      0      1.1
# 19   58    1   2     140.0   211    1        0      165      0      0.0
# 20   60    1   2     130.0   185    0        0      155      0      3.0
# 21   67    0   0     130.0   223    0        1      142      0      0.3
# 22   45    1   0     130.0   208    0        0      148      1      3.0
# 23   63    0   2     135.0   252    0        0      172      0      0.0
# 24   42    0   2     120.0   209    0        1      173      0      0.0
# 25   61    0   0     130.0   307    0        0      146      1      1.0
# 26   44    1   2     130.0   233    0        1      179      1      0.4
# 27   58    0   1     130.0   319    1        0      152      0      0.0
# 28   56    1   2     130.0   256    1        0      142      1      0.6
# 29   55    0   0     180.0   327    0        2      117      1      3.4
#
#     slope  ca  thal  target      thal_category
# 0       2   2     3       0  reversable_defect
# 1       0   0     3       0       fixed_defect
# 2       0   0     3       0  reversable_defect
# 3       2   1     3       0  reversable_defect
# 4       1   3     2       0       fixed_defect
# 5       1   0     2       1       fixed_defect
# 6       0   3     1       0             normal
# 7       1   1     3       0       fixed_defect
# 8       2   0     3       0  reversable_defect
# 9       1   2     2       0       fixed_defect
# 10      1   0     2       1       fixed_defect
# 11      1   0     3       0  reversable_defect
# 12      2   0     2       1       fixed_defect
# 13      1   3     3       0  reversable_defect
# 14      1   0     0       0            unknown
# 15      2   0     2       1       fixed_defect
# 16      2   1     2       1       fixed_defect
# 17      1   1     3       0  reversable_defect
# 18      2   0     2       1       fixed_defect
# 19      2   0     2       1       fixed_defect
# 20      1   0     2       0       fixed_defect
# 21      2   2     2       1       fixed_defect
# 22      1   0     2       1       fixed_defect
# 23      2   0     2       1       fixed_defect
# 24      1   0     2       1       fixed_defect
# 25      1   0     3       0  reversable_defect
# 26      2   0     2       1       fixed_defect
# 27      2   2     2       0       fixed_defect
# 28      1   1     1       0             normal
# 29      1   0     2       0       fixed_defect

# %% [markdown]
# ### График "Скрипичная диаграмма (violin plot)" для колонки "age"

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Построение скрипичной диаграммы
sns.violinplot(data=data, x="age", linewidth=1, linecolor="k")

# Отображение графика
plt.show()
